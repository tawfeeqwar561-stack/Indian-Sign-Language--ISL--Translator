# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 01 — ISL Data Exploration\n",
    "\n",
    "This notebook explores the raw ISL gesture video dataset,\n",
    "extracts statistics, visualises sample frames, and prepares\n",
    "the data for the preprocessing pipeline."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": 'null',
   "metadata": {},
   "outputs": [],
   "source": [
    "import os\n",
    "import sys\n",
    "import json\n",
    "import numpy as np\n",
    "import matplotlib.pyplot as plt\n",
    "import cv2\n",
    "\n",
    "sys.path.insert(0, '../../backend')\n",
    "from config import get_config\n",
    "from preprocessing.hand_tracker import HandPoseTracker\n",
    "from preprocessing.face_detector import FaceDetector\n",
    "\n",
    "config = get_config()\n",
    "print('Config loaded')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# List dataset contents\n",
    "RAW_DIR = '../data/raw'\n",
    "if os.path.isdir(RAW_DIR):\n",
    "    classes = sorted(os.listdir(RAW_DIR))\n",
    "    print(f'Found {len(classes)} sign classes')\n",
    "    for cls in classes[:10]:\n",
    "        n = len(os.listdir(os.path.join(RAW_DIR, cls)))\n",
    "        print(f'  {cls}: {n} videos')\n",
    "else:\n",
    "    print('No raw data found. Place ISL videos in ml_pipeline/data/raw/<class_name>/')"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": null,
   "metadata": {},
   "outputs": [],
   "source": [
    "# Extract keypoints from a sample video\n",
    "tracker = HandPoseTracker(vars(config))\n",
    "\n",
    "sample_video = None  # Replace with actual path\n",
    "if sample_video and os.path.isfile(sample_video):\n",
    "    cap = cv2.VideoCapture(sample_video)\n",
    "    keypoints = []\n",
    "    while cap.isOpened():\n",
    "        ret, frame = cap.read()\n",
    "        if not ret:\n",
    "            break\n",
    "        result = tracker.process_frame(frame)\n",
    "        if result['has_hands']:\n",
    "            keypoints.append(result['combined_keypoints'])\n",
    "    cap.release()\n",
    "    print(f'Extracted {len(keypoints)} frames with hand detections')\n",
    "    if keypoints:\n",
    "        kp_arr = np.array(keypoints)\n",
    "        print(f'Keypoint array shape: {kp_arr.shape}')\n",
    "else:\n",
    "    print('Set sample_video to explore a real video')\n",
    "\n",
    "tracker.release()"
   ]
  }
 ],
 "metadata": {
  "kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"},
  "language_info": {"name": "python", "version": "3.10.0"}
 },
 "nbformat": 4,
 "nbformat_minor": 4
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 38
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "metadata": {},
#       6    "source": [
#       7     "# 01 — ISL Data Exploration\n",
#       8     "\n",
#       9     "This notebook explores the raw ISL gesture video dataset,\n",
#      10     "extracts statistics, visualises sample frames, and prepares\n",
#      11     "the data for the preprocessing pipeline."
#      12    ]
#      13   },
#      14   {
#      15    "cell_type": "code",
#      16    "execution_count": 'null',
#      17    "metadata": {},
#      18    "outputs": [],
#      19    "source": [
#      20     "import os\n",
#      21     "import sys\n",
#      22     "import json\n",
#      23     "import numpy as np\n",
#      24     "import matplotlib.pyplot as plt\n",
# ...
